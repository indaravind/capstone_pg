# %% [markdown]
# # PowerGrid Capstone Notebook
# This notebook demonstrates how to run the packaged pipeline.

# %%
import os
import sys
sys.path.append(os.path.abspath('../'))
from powergrid_capstone.main import main

# Run the full pipeline
main()
